# %%
import matplotlib.pyplot as plt

speedup = [0.903072, 1.030987, 1.730200, 2.256081, 2.397746, 3.346847, 3.421275, 3.562491, 5.130017, 3.750917, 
          4.722430, 4.705679, 5.751849, 3.958920, 6.058689, 5.869837, 5.718282, 5.842025, 8.498644, 7.176636,
          9.271011, 7.886384, 7.658455, 12.507541, 11.843356, 9.757265, 13.757191, 11.529876]

proc_cnt = range(1, 29)
plt.figure(figsize=(12, 7))
plt.title("Speedup versus number of processes graph", fontsize=16)
plt.xlabel("Number of processes", fontsize=20)
plt.ylabel("Speedup", fontsize=20)
plt.plot(proc_cnt, speedup, '-o', label='$N = 10^6$')
plt.legend(prop={ 'size' : 15 })
